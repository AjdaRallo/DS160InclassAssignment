# %% [markdown]
# ## Answer the following question on the countries dataset using Matplotlib and Pandas
# Pair up with a partner you never worked before and submit your work on Moodle by 5 PM to get full credit

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
countries=pd.read_csv("countries.csv")

# %% [markdown]
# #### Q1. Which continents are present in the dataset, and how many countries are there in each continent?

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         1704 non-null   object
#  1   continent       1704 non-null   object
#  2   year            1704 non-null   int64
#  3   lifeExpectancy  1704 non-null   float64
#  4   population      1704 non-null   int64
#  5   gdpPerCapita    1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
countries['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
data_2007=countries[countries['year']==2007]
data_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 11 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         142 non-null    object
#  1   continent       142 non-null    object
#  2   year            142 non-null    int64
#  3   lifeExpectancy  142 non-null    float64
#  4   population      142 non-null    int64
#  5   gdpPerCapita    142 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 7.8+ KB

# %%
data_2007['continent'].value_counts()
# Out:
# Africa      52
# Asia        33
# Europe      30
# Americas    25
# Oceania      2
# Name: continent, dtype: int64

# %% [markdown]
# ### There are 5 continents present and in the year 2007, 52 in africa, 33 in asia, 30 in europe, 25 in america, and 2 in oceania

# %% [markdown]
# ##### Answer: Asia: , Africa: ,...

# %% [markdown]
# #### Q2. What is the distribution of life expectancy across all countries and years?
# ![image.png](attachment:image.png)

# %%
plt.hist(countries['lifeExpectancy'],
        facecolor="skyblue",
        edgecolor="black",
        bins=20)
plt.xlabel("Life Expectancy")
plt.ylabel("Frequency")
plt.title("Distribution of Life Expectancy")
# Out:
# Text(0.5, 1.0, 'Distribution of Life Expectancy')

# %% [markdown]
# #### Q3. How does life expectancy vary over the years for a specific country (e.g., Afghanistan)?
# https://www.geeksforgeeks.org/matplotlib-markers-module-in-python/
# https://www.geeksforgeeks.org/grids-in-matplotlib/
# ![image.png](attachment:image.png)

# %%
afghanistan=countries[countries['country']=="Afghanistan"]
afghanistan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         12 non-null     object
#  1   continent       12 non-null     object
#  2   year            12 non-null     int64
#  3   lifeExpectancy  12 non-null     float64
#  4   population      12 non-null     int64
#  5   gdpPerCapita    12 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 672.0+ bytes

# %%
plt.plot(afghanistan['year'], afghanistan['lifeExpectancy'],
        marker= "o",
        color= "green")
plt.grid(True)
plt.xlabel("Year")
plt.ylabel("Life Expectancy")
plt.title("Life Expectancy Over the Years in Afghanistan")
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over the Years in Afghanistan')

# %% [markdown]
# #### Q4. What is the relationship between GDP per capita and life expectancy?
# ![image.png](attachment:image.png)

# %%
plt.scatter(countries['gdpPerCapita'],
           countries['lifeExpectancy'],
           color="red")
plt.xlabel("Life Expectancy")
plt.ylabel("GDP Per Capita")
plt.title("GDP per Capita vs Life Expectancy")
plt.grid(True)

# %% [markdown]
# #### Q5. How has the population changed over time for a specific continent (e.g., Africa)?
# ![image.png](attachment:image.png)
# ** Use groupby for year with populations

# %%
africa_data=countries[countries['continent']=="Africa"]
pop_data=africa_data.groupby(['year'])['population'].sum()

# %%
plt.plot(pop_data,
         color="red",
        marker="o")
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population Over Time in Africa")
plt.grid(True)

# %% [markdown]
# #### Q6. What is the trend of GDP per capita over the years for a specific continent (e.g., Europe)?
# ![image.png](attachment:image.png)

# %%
Euro_data=countries[countries['continent']=="Europe"]
pop_data1=Euro_data.groupby(['year'])['gdpPerCapita'].mean()
plt.plot(pop_data1,
        color="blue",
        marker="o")
plt.xlabel=("Year")
plt.ylable=("GDP Per Capita")
plt.title=("GDP Per Capita Trend Over Time in Europe")
plt.grid(True)
