# %% [markdown]
# # In class Assignment-
# Analyzing your `time sheet` using Pandas, Matplotlib and Seaborn modules.Save this file as InClassAssignment_Timesheet_xxxx where xxxx will be your initials
# - Name:
# - Date:
# - Version:

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
df=pd.read_csv("Time_Tracking.csv")

# %% [markdown]
# ### Investigate your dataset (head, tail, info)
# - How many entries in your dataset?
# - Is there any missing value?
# - What are the data types?

# %%
df.head()
# Out:
#   Initials       Date     Class ID  Time  \
# 0       AR   1/8/2024  Engl-200-02    60
# 1       AR   1/8/2024  Math-205-02    75
# 2       AR   1/8/2024   IDC-101-02    75
# 3       AR   1/9/2024    DS-160-01    75
# 4       AR  1/10/2024  Engl-200-02   105
#
#                                              Summary
# 0  I did my homework before class, reading three ...
# 1  I went to my math class and took notes during ...
# 2  I went to my IDC, and we went over the course ...
# 3   I went to my Data Science class, and took a quiz
# 4  I read three short stories for class and we we...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Initials  53 non-null     object
#  1   Date      53 non-null     object
#  2   Class ID  53 non-null     object
#  3   Time      53 non-null     int64
#  4   Summary   53 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
df['Class ID'].value_counts()
# Out:
# Engl-200-02    16
# Math-205-02    16
# IDC-101-02     11
# DS-160-01      10
# Name: Class ID, dtype: int64

# %% [markdown]
# #### There are objects (Categorical) and int64s (Numerical) data entries. There are 53 total entries, and no missing values

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations (sample below)
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x="Class ID",
           y="Time",
           data=df)
df.describe()
# Out:
#              Time
# count   53.000000
# mean    94.150943
# std     27.311167
# min     60.000000
# 25%     75.000000
# 50%    100.000000
# 75%    105.000000
# max    225.000000

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days (sample below)
# ![image-2.png](attachment:image-2.png)
# - df['day'] = range(1, len(df) + 1)

# %%
df['Date']=pd.to_datetime(df['Date'])
df['day_name']=df['Date'].dt.day_name()
df['Day']=range(1, len(df)+1)
df
# Out:
#    Initials       Date     Class ID  Time  \
# 0        AR 2024-01-08  Engl-200-02    60
# 1        AR 2024-01-08  Math-205-02    75
# 2        AR 2024-01-08   IDC-101-02    75
# 3        AR 2024-01-09    DS-160-01    75
# 4        AR 2024-01-10  Engl-200-02   105
# 5        AR 2024-01-10  Math-205-02    75
# 6        AR 2024-01-10   IDC-101-02   105
# 7        AR 2024-01-11    DS-160-01    75
# 8        AR 2024-01-12  Engl-200-02   105
# 9        AR 2024-01-12  Math-205-02    75
# 10       AR 2024-01-15  Engl-200-02   105
# 11       AR 2024-01-15  Math-205-02    75
# 12       AR 2024-01-15   IDC-101-02   100
# 13       AR 2024-01-16    DS-160-01    75
# 14       AR 2024-01-17  Engl-200-02   105
# 15       AR 2024-01-17  Math-205-02    75
# 16       AR 2024-01-17   IDC-101-02   105
# 17       AR 2024-01-18    DS-160-01   120
# 18       AR 2024-01-19  Engl-200-02   105
# 19       AR 2024-01-19  Math-205-02    75
# 20       AR 2024-01-22  Engl-200-02   105
# 21       AR 2024-01-22  Math-205-02    75
# 22       AR 2024-01-22   IDC-101-02   105
# 23       AR 2024-01-23    DS-160-01    75
# 24       AR 2024-01-24  Engl-200-02   105
# 25       AR 2024-01-24  Math-205-02    75
# 26       AR 2024-01-24   IDC-101-02   105
# 27       AR 2024-01-25    DS-160-01    75
# 28       AR 2024-01-26  Engl-200-02   105
# 29       AR 2024-01-26  Math-205-02    75
# 30       AR 2024-01-29  Engl-200-02   105
# 31       AR 2024-01-29  Math-205-02    75
# 32       AR 2024-01-29   IDC-101-02   105
# 33       AR 2024-01-30    DS-160-01   105
# 34       AR 2024-01-31  Engl-200-02   105
# 35       AR 2024-01-31  Math-205-02   180
# 36       AR 2024-01-31   IDC-101-02   105
# 37       AR 2024-02-01    DS-160-01    75
# 38       AR 2024-02-02  Engl-200-02   105
# 39       AR 2024-02-02  Math-205-02    75
# 40       AR 2024-02-05  Engl-200-02   105
# 41       AR 2024-02-05  Math-205-02    75
# 42       AR 2024-02-05   IDC-101-02   105
# 43       AR 2024-02-06    DS-160-01   105
# 44       AR 2024-02-07  Engl-200-02    75
# 45       AR 2024-02-07  Math-205-02   120
# 46       AR 2024-02-07   IDC-101-02   105
# 47       AR 2024-02-08    DS-160-01    75
# 48       AR 2024-02-09  Engl-200-02   225
# 49       AR 2024-02-09  Math-205-02    75
# 50       AR 2024-02-12  Engl-200-02    75
# 51       AR 2024-02-12  Math-205-02    75
# 52       AR 2024-02-12   IDC-101-02    75
#
#                                               Summary   day_name  Day
# 0   I did my homework before class, reading three ...     Monday    1
# 1   I went to my math class and took notes during ...     Monday    2
# 2   I went to my IDC, and we went over the course ...     Monday    3
# 3    I went to my Data Science class, and took a quiz    Tuesday    4
# 4   I read three short stories for class and we we...  Wednesday    5
# 5               I took notes over chapter 1 section 1  Wednesday    6
# 6   We went over the chapter in our book that we h...  Wednesday    7
# 7               Python Notes and in class assignment    Thursday    8
# 8   I read three short stories for class and we we...     Friday    9
# 9               I took notes over chapter 1 section 2     Friday   10
# 10  I read two short stories for class and we went...     Monday   11
# 11          I took notes over chapter 1 section 2 & 3     Monday   12
# 12  We went over the chapter in our book that we h...     Monday   13
# 13                       We finished jupiter notebook    Tuesday   14
# 14  I read two short stories for class and we went...  Wednesday   15
# 15              I took notes over chapter 1 section 4  Wednesday   16
# 16  We went over the chapter in our book that we h...  Wednesday   17
# 17                we had an assignment over numpy due   Thursday   18
# 18  I read three short stories for class and we we...     Friday   19
# 19              I took notes over chapter 1 section 5     Friday   20
# 20  I read three short stories for class and we we...     Monday   21
# 21              I took notes over chapter 1 section 6     Monday   22
# 22  We went over the chapter in our book that we h...     Monday   23
# 23                                       Python Notes    Tuesday   24
# 24  I read two short stories for class and we went...  Wednesday   25
# 25              I took notes over chapter 1 section 7  Wednesday   26
# 26  We went over the chapter in our book that we h...  Wednesday   27
# 27                                       Python Notes   Thursday   28
# 28  I read three short stories for class and we we...     Friday   29
# 29              I took notes over chapter 1 section 8     Friday   30
# 30  I read two short stories for class and we went...     Monday   31
# 31    I took notes over the last section of chapter 1     Monday   32
# 32  We went over the chapter in our book that we h...     Monday   33
# 33                        Pandas in class assingment     Tuesday   34
# 34  I read three short stories for class and we we...  Wednesday   35
# 35  I took notes over Chapter 2 section 1 and work...  Wednesday   36
# 36  We went over the chapter in our book that we h...  Wednesday   37
# 37                                       Python Notes   Thursday   38
# 38  I read a short story and we went over it durin...     Friday   39
# 39  I took notes over Chapter 2 sections 1 & 2 and...     Friday   40
# 40  I read three short stories for class and we we...     Monday   41
# 41              I took notes over chapter 2 section 3     Monday   42
# 42  We went over the chapter in our book that we h...     Monday   43
# 43               we worked on an in class assignment     Tuesday   44
# 44                We went over a short story in class  Wednesday   45
# 45  I took notes over chapter 2 section 4 and work...  Wednesday   46
# 46  We went over the chapter in our book that we h...  Wednesday   47
# 47                                       Python Notes   Thursday   48
# 48  I read three short stories for class and we we...     Friday   49
# 49              I took notes over chapter 2 section 5     Friday   50
# 50                We went over a short story in class     Monday   51
# 51                  I took a test over chapters 1 & 2     Monday   52
# 52  We went over the chapter in our book that we h...     Monday   53

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram to visually represent the distribution of time spent.
# 2. Create a  bar chart (sample below) to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
sns.histplot(x='Time',
            data=df)
plt.show()

# %%
sns.barplot(x='Class ID',
           y='Time',
           data=df)
plt.show()

# %% [markdown]
# #### Most time spent in English, and least time spent in Data Science, this is likely because of how oftne I have each class, I have english 3 times a week and data science only two.

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see `how often` you engaged in each.

# %%
df['Class ID'].value_counts()
# Out:
# Engl-200-02    16
# Math-205-02    16
# IDC-101-02     11
# DS-160-01      10
# Name: Class ID, dtype: int64

# %% [markdown]
# ### I Went to math and english the most with 16 occurences, then IDC with 11 and finally DS with 10 total occurences

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart (sample below) to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='Day',
            y='Time',
            hue="Class ID",
            data=df)
plt.show()

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
time_spent=df['Time'].sum()
print(time_spent)
# Out:
# 4990

# %%
df.groupby(['Class ID'])['Time'].sum()
# Out:
# Class ID
# DS-160-01       855
# Engl-200-02    1695
# IDC-101-02     1090
# Math-205-02    1350
# Name: Time, dtype: int64

# %% [markdown]
# #### English recieved the most time spent by a considerable margin, followed by Math and then IDC and finally Data Science taking the least amount of time

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less (sample below).
# ![image.png](attachment:image.png)

# %%
corr=df[['Day',
        'Time']].corr()
print(corr)
sns.heatmap(corr, annot=True)
# Out:
#            Day      Time
# Day   1.000000  0.213154
# Time  0.213154  1.000000
# <Axes: >

# %% [markdown]
# ### Your Reflection on the findings

# %% [markdown]
# #### Based on every graph created and the data on each, I can say that I spent more time working on English assignments (Both in class and outside of class) than any other class. I can also see that I spent the least amount of time working on assignments in Data Science, likely due to the fact that we don't have a lot of out of class work and only meet twice a week.

# %% [markdown]
# ### Submit the work by Friday 16th end of the day
